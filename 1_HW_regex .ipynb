# %% [markdown]
# # Instructions HW - Regular Expression - 10 Points
# - **You have to submit two files for this part of the HW (1) ipynb (colab notebook) and (2) pdf file**
# # **You have to use only regular expressions for this HW. Please do not use spacy for the tasks in this notebook**

# %% [markdown]
# ## import libraries
#
# > Indented block

# %%
# !pip install swifter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 830 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 281 kB 43.1 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 40.6 MB/s
# ...
#   Created wheel for swifter: filename=swifter-1.3.4-py3-none-any.whl size=16322 sha256=c450d566f3fdfe3a5675c01aae9fb220eafffad1812101d60190112c5219e2d9
#   Stored in directory: /root/.cache/pip/wheels/29/a7/0e/3a8f17ac69d759e1e93647114bc9bdc95957e5b0cbfd405205
# Successfully built swifter
# ...
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
# ...

# %%
# import libraries
import pandas as pd
from pathlib import Path
import zipfile
import tarfile
import numpy as np
import swifter
import re
import string
import random

# %% [markdown]
# ## Mount Google drive and Specify folder paths

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# specify the main folder in googe drive where you will save your datasets for the course
# this is a string                                 
# PLEASE CHNAGE THE PATH to WHERE YOU WANT TO SAVE THE DATA
basepath = 'C:/Users/kusha/OneDrive/Desktop/Fall-22/NLP'

# %%
# specify pathlib folder
# This is a system Path(PosixPath)
base_folder = Path(basepath)

# %%
# check current working directory
Path.cwd()
# Out:
# PosixPath('/content')

# %%
# I have two separate folders - archive and data for storing cpmpressed files and main data respectively
archive = base_folder/'archive'
data_folder = base_folder/'data'

# %% [markdown]
# # Task 1 : We will perform following tasks- 6 Points
# - Download data (using wget)
# - Clean data using regular expression

# %% [markdown]
# ## Run the comand below to Download the data and create dataframe
# Download the dats set from foillowing URL: "http://www.trackmyhashtag.com/data/COVID-19.zip"

# %%
# Download a  file to the filesystem from a url using the wget commmand
# syntax  !wget {url} -P {path_to_save_file}

URL = "http://www.trackmyhashtag.com/data/COVID-19.zip" 
# !wget {URL} -P {archive}
# Out:
# --2022-08-30 03:31:56--  http://www.trackmyhashtag.com/data/COVID-19.zip
# Resolving www.trackmyhashtag.com (www.trackmyhashtag.com)... 138.197.74.186
# Connecting to www.trackmyhashtag.com (www.trackmyhashtag.com)|138.197.74.186|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.trackmyhashtag.com/data/COVID-19.zip [following]
# --2022-08-30 03:31:57--  https://www.trackmyhashtag.com/data/COVID-19.zip
# Connecting to www.trackmyhashtag.com (www.trackmyhashtag.com)|138.197.74.186|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13772919 (13M) [application/zip]
# Saving to: ‘C:/Users/kusha/OneDrive/Desktop/Fall-22/NLP/archive/COVID-19.zip’
#
# COVID-19.zip        100%[===================>]  13.13M  5.69MB/s    in 2.3s
#
# 2022-08-30 03:32:00 (5.69 MB/s) - ‘C:/Users/kusha/OneDrive/Desktop/Fall-22/NLP/archive/COVID-19.zip’ saved [13772919/13772919]

# %%
# use .namelist() to see the content of zipped folder
file = archive / 'COVID-19.zip'
with zipfile.ZipFile(file, 'r') as f:
  print(f.namelist())
# Out:
# ['COVID.csv', 'COVID-images.csv', 'COVID-videos.csv']

# %%
# extract the file - COVID.csv
file = archive / 'COVID-19.zip'
with zipfile.ZipFile(file, 'r') as f:
  f.extract('COVID.csv', path = data_folder)

# %%
for entries in data_folder.iterdir():
  print(entries.name)
# Out:
# COVID.csv

# %%
# data file -COVID.csv
file = data_folder / 'COVID.csv'  
# Import the dataset using the Pandas library
df = pd.read_csv(file)
# Inspect the dataset
df.head()
# Out:
#                 Tweet Id                                          Tweet URL  \
# 0  "1233417783175778304"  https://twitter.com/Giussi92/status/1233417783...
# 1  "1233417742520332290"  https://twitter.com/LAMofficial/status/1233417...
# 2  "1233417741027225602"  https://twitter.com/mitchellvii/status/1233417...
# 3  "1233417699264356357"  https://twitter.com/HelenKennedy/status/123341...
# 4  "1233417674274807808"  https://twitter.com/W7VOA/status/1233417674274...
#
#   Tweet Posted Time (UTC)                                      Tweet Content  \
# 0    28 Feb 2020 15:44:49  Also the entire Swiss Football League is on ho...
# 1    28 Feb 2020 15:44:40  World Health Org Official: Trump’s press confe...
# 2    28 Feb 2020 15:44:39  I mean, Liberals are cheer-leading this #Coron...
# 3    28 Feb 2020 15:44:29  Under repeated questioning, Pompeo refuses to ...
# 4    28 Feb 2020 15:44:23  #coronavirus comments now from @larry_kudlow h...
#
# ...

# %%
# Let us look at the text column
for text in df['Tweet Content'].iloc[100:110]:
  print(text)
# Out:
# As the #coronavirus continues its deadly spread across the globe, #BigLaw firms impose travel restrictions and urge employees to work from home. #COVID19 https://t.co/fM67oYDeqG
# #AlaskaAirlines suspends change, cancellation fees for new flight bookings due to #coronavirus | Read more: https://t.co/6KK1kTMcnj https://t.co/X4n2WUpQDn
# Defunding programs that help low-income families heat their homes in the winter is unconscionable.
#
# @HouseDemocrats will ensure we have the necessary resources to address the #coronavirus without skimming money from programs that help the most vulnerable. https://t.co/WrgofbG3Le
# European shares plunge again as global shares head for worst week since crisis #coronavirus https://t.co/55hT6RUzvn
# ICYMI: President @realDonaldTrump calls out Nancy Pelosi on #Coronavirus, says she is clearly "trying to create a panic."
#
#  "I think Speaker Pelosi is incompetent." https://t.co/c0P3xmOsBj
# ...

# %% [markdown]
# ## 1.1 Change  the hashtags to lower case
# e.g. replace #Coronavirus with #coronavirus
#
# Create a new column clean_text. The clean_text should have modified hashtags.

# %%
def Extract_Clean(s):
  for var in re.findall(r'#\w+', s):
    s = s.replace(var, str(var).lower())
  return s
 
df['clean_text'] = df['Tweet Content'].swifter.apply(lambda x: Extract_Clean(x))

df['Tweet Content']
# Out:
# Pandas Apply:   0%|          | 0/60160 [00:00<?, ?it/s]
# 0        Also the entire Swiss Football League is on ho...
# 1        World Health Org Official: Trump’s press confe...
# 2        I mean, Liberals are cheer-leading this #Coron...
# 3        Under repeated questioning, Pompeo refuses to ...
# 4        #coronavirus comments now from @larry_kudlow h...
#                                ...
# 60155    El #coronavirus entérico felino es un virus in...
# 60156    RT @timhquotes: It's my party, you're invited!...
# 60157    It's my party, you're invited!\n\nPS, this is ...
# 60158    Amy’s a survivor! #bariclab #pnnl #movingon #c...
# 60159    A review of asymptomatic and sub-clinical Midd...
# Name: Tweet Content, Length: 60160, dtype: object

# %% [markdown]
# ## 1.2 Remove RT from text in column clean_text

# %%
regex=r"[RT]{2}" # regex for removing RT # doubtful
df['clean_text'] = df['clean_text'].swifter.apply(lambda x: re.sub(regex,'',x))
# Out:
# Pandas Apply:   0%|          | 0/60160 [00:00<?, ?it/s]

# %% [markdown]
# ## 1.3 Remove URLs and links from text in column clean_text

# %%
df['clean_text'] = df['clean_text'].swifter.apply(lambda x: re.sub('https?[A-Za-z0-9:/._\-]+','',x))
df['clean_text']
# Out:
# Pandas Apply:   0%|          | 0/60160 [00:00<?, ?it/s]
# 0        Also the entire Swiss Football League is on ho...
# 1        World Health Org Official: Trump’s press confe...
# 2        I mean, Liberals are cheer-leading this #coron...
# 3        Under repeated questioning, Pompeo refuses to ...
# 4        #coronavirus comments now from @larry_kudlow h...
#                                ...
# 60155    El #coronavirus entérico felino es un virus in...
# 60156     @timhquotes: It's my party, you're invited!\n...
# 60157    It's my party, you're invited!\n\nPS, this is ...
# 60158    Amy’s a survivor! #bariclab #pnnl #movingon #c...
# 60159    A review of asymptomatic and sub-clinical Midd...
# Name: clean_text, Length: 60160, dtype: object

# %% [markdown]
# ## 1.4 Removing Punctuations from text in column clean_text.
# Hint: Use the following function
# ```python
# text.translate(str.maketrans('', '', string.punctuation))
# ```

# %%
df['clean_text']=df['clean_text'].swifter.apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))
df['clean_text']
# Out:
# Pandas Apply:   0%|          | 0/60160 [00:00<?, ?it/s]
# 0        Also the entire Swiss Football League is on ho...
# 1        World Health Org Official Trump’s press confer...
# 2        I mean Liberals are cheerleading this coronavi...
# 3        Under repeated questioning Pompeo refuses to s...
# 4          coronavirus comments now from larrykudlow here
#                                ...
# 60155    El coronavirus entérico felino es un virus int...
# 60156     timhquotes Its my party youre invited\n\nPS t...
# 60157    Its my party youre invited\n\nPS this is my li...
# 60158    Amy’s a survivor bariclab pnnl movingon corona...
# 60159    A review of asymptomatic and subclinical Middl...
# Name: clean_text, Length: 60160, dtype: object

# %% [markdown]
# ## 1.5 Extract number of Hashtags in a new column num_hashtags

# %%
def Hashtags(text):
  return len(re.findall(r'#\w', text))
 
df['num_hashtags'] = df['Tweet Content'].apply(Hashtags)
df['num_hashtags']
# Out:
# 0        1
# 1        1
# 2        2
# 3        1
# 4        1
#         ..
# 60155    4
# 60156    6
# 60157    6
# 60158    8
# 60159    1
# Name: num_hashtags, Length: 60160, dtype: int64

# %% [markdown]
# ## 1.6 Extract number of user mentions in a new column num_mentions

# %%
def User_Count(text):
  return len(re.findall(r'@\w', text))
 
df['num_mentions'] = df['Tweet Content'].apply(User_Count)
df['num_mentions']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 60155    0
# 60156    1
# 60157    0
# 60158    0
# 60159    0
# Name: num_mentions, Length: 60160, dtype: int64

# %% [markdown]
# ## 1.7 Count number of mentions and hashtags

# %%
num_mentions=df['num_mentions'].sum()
num_mentions
# Out:
# 68144

# %%
num_hashtags=df['num_hashtags'].sum()
num_hashtags
# Out:
# 134998

# %% [markdown]
# # Task2 - 4 Points

# %% [markdown]
# For this task, we will download the data from the following link:
# https://s3.amazonaws.com/fast-ai-imageclas/oxford-iiit-pet.tgz
#
# This is a 37 category pet dataset with roughly 200 images for each class.

# %% [markdown]
# ## Downlaod the compressed file
# **Do not untar/unzip the cpmpressed file**
#
# The link has only one compressed file: oxford-iiit-pet.tgz

# %%
URL = 'https://s3.amazonaws.com/fast-ai-imageclas/oxford-iiit-pet.tgz'
# !wget {URL} -P {archive}
# Out:
# --2022-08-30 03:32:37--  https://s3.amazonaws.com/fast-ai-imageclas/oxford-iiit-pet.tgz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.202.176
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.202.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 811706944 (774M) [application/x-tar]
# Saving to: ‘C:/Users/kusha/OneDrive/Desktop/Fall-22/NLP/archive/oxford-iiit-pet.tgz’
#
# oxford-iiit-pet.tgz 100%[===================>] 774.10M  15.6MB/s    in 53s
#
# 2022-08-30 03:33:31 (14.7 MB/s) - ‘C:/Users/kusha/OneDrive/Desktop/Fall-22/NLP/archive/oxford-iiit-pet.tgz’ saved [811706944/811706944]

# %% [markdown]
# ## Run the command below to Extract the entity names
#
# Here we will extract filenames and store the names in the variable `filenames`
#
# We will not untar/unzip the compresed file. These are images of cats and dogs. We do not need images for this task. We only need file names for this task.

# %%
with  tarfile.open(archive/'oxford-iiit-pet.tgz', 'r') as tar:
  filenames = tar.getnames()

# %%
#hstack vstack configurations

import numpy as np
arr1=np.array([[1],[2]])
arr2=np.array([[4],[6]])
print(np.hstack((arr1,arr2)))
# Out:
# [[1 4]
#  [2 6]]

# %%
df = pd.DataFrame(filenames, columns =['filename'])
df
# Out:
#                                                 filename
# 0                                        oxford-iiit-pet
# 1                                 oxford-iiit-pet/images
# 2                  oxford-iiit-pet/images/Siamese_87.jpg
# 3               oxford-iiit-pet/images/chihuahua_126.jpg
# 4       oxford-iiit-pet/images/german_shorthaired_97.jpg
# ...                                                  ...
# 25864  oxford-iiit-pet/annotations/trimaps/wheaten_te...
# 25865  oxford-iiit-pet/annotations/trimaps/wheaten_te...
# 25866  oxford-iiit-pet/annotations/trimaps/Egyptian_M...
# 25867  oxford-iiit-pet/annotations/trimaps/._Birman_1...
# 25868  oxford-iiit-pet/annotations/trimaps/saint_bern...
#
# [25869 rows x 1 columns]

# %% [markdown]
# ## Create DataFrame
# We will now create the Dataframe

# %%
# check the content using df.head() 
df.head()
# Out:
#                                            filename
# 0                                   oxford-iiit-pet
# 1                            oxford-iiit-pet/images
# 2             oxford-iiit-pet/images/Siamese_87.jpg
# 3          oxford-iiit-pet/images/chihuahua_126.jpg
# 4  oxford-iiit-pet/images/german_shorthaired_97.jpg

# %%
# check the data using df.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25869 entries, 0 to 25868
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  25869 non-null  object
# dtypes: object(1)
# memory usage: 202.2+ KB

# %%
df.head()
# Out:
#                                            filename
# 0                                   oxford-iiit-pet
# 1                            oxford-iiit-pet/images
# 2             oxford-iiit-pet/images/Siamese_87.jpg
# 3          oxford-iiit-pet/images/chihuahua_126.jpg
# 4  oxford-iiit-pet/images/german_shorthaired_97.jpg

# %% [markdown]
# ## Task 2.1 Keep rows with name of  image files only
# We ony need file names for images. The images are in the folder oxford-iiit-pet/images and end with .jpg.
#
# For this task you will need to write a regular expression that matches the file names that have the word `images` in it and end with `.jpg`.
#
# Use this expression to keep ony those rows that corresponds to images.

# %%
# code here 
regex=r"(\.jpg$)" 
df['filename']=df[df['filename'].str.contains(regex)]
df.dropna(inplace=True)























# ---------------------------------------rough work--------------------------------------
# regex=r"(\.jpg$)" 
# temp_file=[]
# for i,fil in enumerate(df['filename']):
#   match=re.search(regex,str(fil))
#   if match:
#     temp_file.append(df['filename'].iloc[i])
#   else: 
#     pass
                                                      

# df['temp_file']=pd.DataFrame({'temp_file':temp_file})

# df['temp_file'].dropna()
# df['temp_file']

# df_fin=df['temp_file'].copy()

# df_fin=df_fin.dropna()
# df_fin
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# check the head using df.head

df.head()





# df_find=pd.DataFrame(df_fin)   
# df_find.rename(columns={"temp_file": "filenames"},errors='raise')
# print(df_find.head())
# Out:
#                                            filename
# 2             oxford-iiit-pet/images/Siamese_87.jpg
# 3          oxford-iiit-pet/images/chihuahua_126.jpg
# 4  oxford-iiit-pet/images/german_shorthaired_97.jpg
# 5             oxford-iiit-pet/images/Bombay_157.jpg
# 6              oxford-iiit-pet/images/Bengal_12.jpg

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7390 entries, 2 to 7394
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  7390 non-null   object
# dtypes: object(1)
# memory usage: 115.5+ KB

# %%
## DONOT WRITE ANYTHING - This just shows you the output for the above command

# %%
## DONOT WRITE ANYTHING - This just shows you the output for the above command
## Your output should have 7390 rows.

# %% [markdown]
# ## Task 2.2 Extract image names from files names
#
# The part after `images` in file names represent the image names. For example  for the file name `oxford-iiit-pet/images/newfoundland_61.jpg`, image name is `newfoundland_61.jpg`
#
# Extract only image names from filenames and store them in a separate column.

# %%
regex=r"(?<=images/).*"
df['image_names'] = df['filename'].swifter.apply(lambda x :re.search(regex,x).group())   
df
# Out:
# Pandas Apply:   0%|          | 0/7390 [00:00<?, ?it/s]
#                                                filename  \
# 2                 oxford-iiit-pet/images/Siamese_87.jpg
# 3              oxford-iiit-pet/images/chihuahua_126.jpg
# 4      oxford-iiit-pet/images/german_shorthaired_97.jpg
# 5                 oxford-iiit-pet/images/Bombay_157.jpg
# 6                  oxford-iiit-pet/images/Bengal_12.jpg
# ...                                                 ...
# 7390              oxford-iiit-pet/images/beagle_120.jpg
# 7391           oxford-iiit-pet/images/pomeranian_10.jpg
# 7392         oxford-iiit-pet/images/newfoundland_61.jpg
# 7393    oxford-iiit-pet/images/British_Shorthair_21.jpg
# 7394  oxford-iiit-pet/images/german_shorthaired_151.jpg
#
#                      image_names
# 2                 Siamese_87.jpg
# 3              chihuahua_126.jpg
# 4      german_shorthaired_97.jpg
# 5                 Bombay_157.jpg
# 6                  Bengal_12.jpg
# ...

# %%
## DONOT WRITE ANYTHING - This just shows you the output for the above command
# Out:
#                                                filename                 image_names
# 2                 oxford-iiit-pet/images/Siamese_87.jpg              Siamese_87.jpg
# 3              oxford-iiit-pet/images/chihuahua_126.jpg           chihuahua_126.jpg
# 4      oxford-iiit-pet/images/german_shorthaired_97.jpg   german_shorthaired_97.jpg
# 5                 oxford-iiit-pet/images/Bombay_157.jpg              Bombay_157.jpg
# 6                  oxford-iiit-pet/images/Bengal_12.jpg               Bengal_12.jpg
# ...                                                 ...                         ...
# 7390              oxford-iiit-pet/images/beagle_120.jpg              beagle_120.jpg
# 7391           oxford-iiit-pet/images/pomeranian_10.jpg           pomeranian_10.jpg
# 7392         oxford-iiit-pet/images/newfoundland_61.jpg         newfoundland_61.jpg
# 7393    oxford-iiit-pet/images/British_Shorthair_21.jpg    British_Shorthair_21.jpg
# ...

# %% [markdown]
# ## Task 2.3  Extract label names from image names
# Each image correspond to image of a unique breed of a dog or a cat. The ML task would be to predict the breed of cat/dog given the image file. To do this task we first need to get the outcome (label or dependent varible) from the file names. In this dataset the part before the _number.jpg represents the breed name. For example for image name `german_shorthaired_151.jpg` the breed name is erman_shorthaired. Keep in mind that same breed names are single words and some are multiple words separated by underscores.
#
# Extract the label names as new column in teh dataframe.

# %%
def extract_label(x):
  result = re.match(r'^(\w+)_\d+\.jpg', x)
  if result is not None:
    label = result.group(1)
  else:
    label = 'Error' 
  return label

# %%
df['label'] =df['image_names'].swifter.apply(lambda x:extract_label(x))
# Out:
# Pandas Apply:   0%|          | 0/7390 [00:00<?, ?it/s]

# %%
df
# Out:
#                                                filename  \
# 2                 oxford-iiit-pet/images/Siamese_87.jpg
# 3              oxford-iiit-pet/images/chihuahua_126.jpg
# 4      oxford-iiit-pet/images/german_shorthaired_97.jpg
# 5                 oxford-iiit-pet/images/Bombay_157.jpg
# 6                  oxford-iiit-pet/images/Bengal_12.jpg
# ...                                                 ...
# 7390              oxford-iiit-pet/images/beagle_120.jpg
# 7391           oxford-iiit-pet/images/pomeranian_10.jpg
# 7392         oxford-iiit-pet/images/newfoundland_61.jpg
# 7393    oxford-iiit-pet/images/British_Shorthair_21.jpg
# 7394  oxford-iiit-pet/images/german_shorthaired_151.jpg
#
#                      image_names               label
# 2                 Siamese_87.jpg             Siamese
# 3              chihuahua_126.jpg           chihuahua
# 4      german_shorthaired_97.jpg  german_shorthaired
# 5                 Bombay_157.jpg              Bombay
# ...

# %%
## DONOT WRITE ANYTHING - This just shows you the output for the above command
# Out:
#                                                filename  ...               label
# 2                 oxford-iiit-pet/images/Siamese_87.jpg  ...             Siamese
# 3              oxford-iiit-pet/images/chihuahua_126.jpg  ...           chihuahua
# 4      oxford-iiit-pet/images/german_shorthaired_97.jpg  ...  german_shorthaired
# 5                 oxford-iiit-pet/images/Bombay_157.jpg  ...              Bombay
# 6                  oxford-iiit-pet/images/Bengal_12.jpg  ...              Bengal
# ...                                                 ...  ...                 ...
# 7390              oxford-iiit-pet/images/beagle_120.jpg  ...              beagle
# 7391           oxford-iiit-pet/images/pomeranian_10.jpg  ...          pomeranian
# 7392         oxford-iiit-pet/images/newfoundland_61.jpg  ...        newfoundland
# 7393    oxford-iiit-pet/images/British_Shorthair_21.jpg  ...   British_Shorthair
# 7394  oxford-iiit-pet/images/german_shorthaired_151.jpg  ...  german_shorthaired
#
# ...

# %% [markdown]
# **If you have done everything correctly the comand below will give you 37 as output**

# %%
len(df.label.value_counts())
# Out:
# 37

# %%
# check number of images for each breed
df.label.value_counts()
# Out:
# Siamese                       200
# chihuahua                     200
# leonberger                    200
# english_cocker_spaniel        200
# saint_bernard                 200
# Birman                        200
# shiba_inu                     200
# Sphynx                        200
# american_bulldog              200
# pug                           200
# samoyed                       200
# Russian_Blue                  200
# Ragdoll                       200
# Persian                       200
# British_Shorthair             200
# pomeranian                    200
# newfoundland                  200
# great_pyrenees                200
# beagle                        200
# Abyssinian                    200
# miniature_pinscher            200
# german_shorthaired            200
# Bombay                        200
# Bengal                        200
# japanese_chin                 200
# havanese                      200
# yorkshire_terrier             200
# ...

# %%
## DONOT WRITE ANYTHING - This just shows you the output for the above command
# Out:
# Maine_Coon                    200
# shiba_inu                     200
# pomeranian                    200
# Abyssinian                    200
# Egyptian_Mau                  200
# wheaten_terrier               200
# english_cocker_spaniel        200
# american_bulldog              200
# Birman                        200
# great_pyrenees                200
# Siamese                       200
# Russian_Blue                  200
# german_shorthaired            200
# Bombay                        200
# miniature_pinscher            200
# leonberger                    200
# Ragdoll                       200
# english_setter                200
# saint_bernard                 200
# pug                           200
# american_pit_bull_terrier     200
# basset_hound                  200
# Bengal                        200
# British_Shorthair             200
# japanese_chin                 200
# Persian                       200
# newfoundland                  200
# ...

# %% [markdown]
# ## Task 2.4 Check whether breed name is a Cat or Dog
# If the first alphabet  of the breed name is a capital letter then it is a cat else it is a dog. For example `Siamese` is a Cat whereas `chihuahua` is a dog.
#
# Add a new column `Cat' which takes the value of $1$ if breed corresponds t0 a cat and $0$ if it corresponds to a dog.

# %%
df['Cat'] = df['label'].apply(lambda x: 1 if( x[0].isupper()) else 0)

# %%
df
# Out:
#                                                filename  \
# 2                 oxford-iiit-pet/images/Siamese_87.jpg
# 3              oxford-iiit-pet/images/chihuahua_126.jpg
# 4      oxford-iiit-pet/images/german_shorthaired_97.jpg
# 5                 oxford-iiit-pet/images/Bombay_157.jpg
# 6                  oxford-iiit-pet/images/Bengal_12.jpg
# ...                                                 ...
# 7390              oxford-iiit-pet/images/beagle_120.jpg
# 7391           oxford-iiit-pet/images/pomeranian_10.jpg
# 7392         oxford-iiit-pet/images/newfoundland_61.jpg
# 7393    oxford-iiit-pet/images/British_Shorthair_21.jpg
# 7394  oxford-iiit-pet/images/german_shorthaired_151.jpg
#
#                      image_names               label  Cat
# 2                 Siamese_87.jpg             Siamese    1
# 3              chihuahua_126.jpg           chihuahua    0
# 4      german_shorthaired_97.jpg  german_shorthaired    0
# ...

# %%
## DONOT WRITE ANYTHING - This just shows you the final dataset
# Out:
#                                                filename  ... Cat
# 2                 oxford-iiit-pet/images/Siamese_87.jpg  ...   1
# 3              oxford-iiit-pet/images/chihuahua_126.jpg  ...   0
# 4      oxford-iiit-pet/images/german_shorthaired_97.jpg  ...   0
# 5                 oxford-iiit-pet/images/Bombay_157.jpg  ...   1
# 6                  oxford-iiit-pet/images/Bengal_12.jpg  ...   1
# ...                                                 ...  ...  ..
# 7390              oxford-iiit-pet/images/beagle_120.jpg  ...   0
# 7391           oxford-iiit-pet/images/pomeranian_10.jpg  ...   0
# 7392         oxford-iiit-pet/images/newfoundland_61.jpg  ...   0
# 7393    oxford-iiit-pet/images/British_Shorthair_21.jpg  ...   1
# 7394  oxford-iiit-pet/images/german_shorthaired_151.jpg  ...   0
#
# [7390 rows x 4 columns]

# %%
# end of the assignment
